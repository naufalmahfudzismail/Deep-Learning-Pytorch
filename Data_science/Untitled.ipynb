# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('sma_jkt.csv')
data.head()
# Out:
#        npsn        nama_sekolah                    alamat    kelurahan  \
# 0  20100170        SMA Kanisius       Jl. Menteng Raya 64  Kebon Sirih
# 1  20100173        SMA Paskalis             Jl. Ranjau 13   Sumur Batu
# 2  20100174  SMA Perg. Nasional    Jl. Cempaka Baru Timur   Sumur Batu
# 3  20100175  SMA Advent Salemba        Jl Salemba Raya 47      Paseban
# 4  20100177         SMA PGRI 14  Jl. Setia Kawan 3 No. 25       Gambir
#
#    kecamatan  jumlah_siswa  jumlah_guru                 kepala_sekolah  \
# 0    Menteng           700         44.0           J. HERU HENDARTO, SJ
# 1  Kemayoran           132         11.0              Rebertus Hemu, SS
# 2  Kemayoran            59         11.0                            NaN
# 3  S e n e n           140         15.0  Lis Indriastuti Hardiningsih,
# 4     Gambir            35          8.0               ASALTA SEMBIRING
#
#    telp_sekolah           akreditasi  latitude   longitude
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 12 columns):
# npsn              487 non-null object
# nama_sekolah      489 non-null object
# alamat            489 non-null object
# kelurahan         489 non-null object
# kecamatan         489 non-null object
# jumlah_siswa      489 non-null int64
# jumlah_guru       483 non-null float64
# kepala_sekolah    451 non-null object
# telp_sekolah      483 non-null object
# akreditasi        487 non-null object
# latitude          453 non-null float64
# longitude         453 non-null float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 45.9+ KB

# %%
data.describe()
# Out:
#        jumlah_siswa  jumlah_guru    latitude   longitude
# count    489.000000   483.000000  453.000000  453.000000
# mean     274.188139    26.670807   -6.204636  106.824903
# std      265.689594    14.941008    0.074469    0.074421
# min        0.000000     1.000000   -6.831600  106.385101
# 25%       59.000000    15.000000   -6.244912  106.783592
# 50%      176.000000    22.000000   -6.189925  106.827629
# 75%      465.000000    38.000000   -6.152843  106.874786
# max     1046.000000    79.000000   -6.088325  106.969810

# %%
data = pd.read_csv('sma_jkt.csv', header=None)
X = np.array(data[0][5])
Y = np.array(data[0][6])
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X, Y, color = 'red', linewidth = 3)
ax.scatter([2, 4 ,6], [5, 15 , 25], color = 'dark green', marker = '^')
ax.set_xlim(1, 6.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     157     try:
# --> 158         rgba = _colors_full_map.cache[c, alpha]
#     159     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('d', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4125             try:
# -> 4126                 mcolors.to_rgba_array(co)
#    4127             except ValueError:
#
# ~\AppData\Roaming\Python\Python36\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
# ...
